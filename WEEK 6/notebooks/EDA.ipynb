# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/raw/dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 899 entries, 0 to 898
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  899 non-null    int64
#  1   Survived     899 non-null    int64
#  2   Pclass       899 non-null    int64
#  3   Name         899 non-null    str
#  4   Sex          899 non-null    str
#  5   Age          722 non-null    float64
#  6   SibSp        899 non-null    int64
#  7   Parch        899 non-null    int64
#  8   Ticket       899 non-null    str
#  9   Fare         899 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     897 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 84.4 KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   899.000000  899.000000  899.000000  722.000000  899.000000
# mean    449.959956    0.380423    2.314794   29.724612    0.518354
# std     259.594708    0.485761    0.834870   14.447692    1.098920
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     225.500000    0.000000    2.000000   21.000000    0.000000
# 50%     450.000000    0.000000    3.000000   28.000000    0.000000
# 75%     674.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  899.000000  899.000000
# mean     0.378198   31.986595
# std      0.803259   49.524918
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   30.847900
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          695
# Embarked         2
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
sns.countplot(x="Survived", data=df)
plt.title("Survival Distribution")
plt.show()

# %%
sns.histplot(df["Age"], kde=True)
plt.title("Age Distribution")
plt.show()

# %%
sns.countplot(x="Pclass", hue="Survived", data=df)
plt.title("Passenger Class vs Survival")
plt.show()

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    557
# 1    342
# Name: count, dtype: int64

# %%
df.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.186325
# Name: Survived, dtype: float64
